# %%
import numpy as np

# %%
import pandas as pd

# %%
#help(pd.Series)

# %% [markdown]
# **List to Series**

# %%
myindex = ['USA', 'Canada', 'Mexico']

# %%
mydata = [1776, 1867,1821]

# %%
myser1 = pd.Series(data=mydata)

# %%
myser1
# Out:
# 0    1776
# 1    1867
# 2    1821
# dtype: int64

# %%
myser1[0]
# Out:
# np.int64(1776)

# %%
myser = pd.Series(data= mydata, index= myindex)

# %%
myser
# Out:
# USA       1776
# Canada    1867
# Mexico    1821
# dtype: int64

# %%
myser['USA']
# Out:
# np.int64(1776)

# %%
#myser[0] 
# if labeled index present, and numeric index used,that rasies Key error

# %% [markdown]
# **Dict to series**

# %%
ages = {'Pranalini':7, 'Neha':6, 'Mayon':2}

# %%
myser2 = pd.Series(ages)

# %%
myser2
# Out:
# Pranalini    7
# Neha         6
# Mayon        2
# dtype: int64

# %%
myser2['Neha']
# Out:
# np.int64(6)

# %% [markdown]
# **Pandas Series Operation**

# %%
# Imaginary Sales Data for 1st and 2nd Quarters for Global Company
q1 = {'Japan': 80, 'China': 450, 'India': 200, 'USA': 250}
q2 = {'Brazil': 100,'China': 500, 'India': 210,'USA': 260}

# %%
sales_q1=pd.Series(q1)

# %%
sales_q2=pd.Series(q2)

# %%
sales_q1
# Out:
# Japan     80
# China    450
# India    200
# USA      250
# dtype: int64

# %%
sales_q2
# Out:
# Brazil    100
# China     500
# India     210
# USA       260
# dtype: int64

# %%
sales_q1.keys()
# Out:
# Index(['Japan', 'China', 'India', 'USA'], dtype='str')

# %%
sales_q1 * 2
# Out:
# Japan    160
# China    900
# India    400
# USA      500
# dtype: int64

# %%
sales_q1 + sales_q2
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64

# %%
sales_q1.add(sales_q2,fill_value=0) 
#though the series values are int, when numeric operations started, values type changed to float
# Out:
# Brazil    100.0
# China     950.0
# India     410.0
# Japan      80.0
# USA       510.0
# dtype: float64
